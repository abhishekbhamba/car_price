# %% [markdown]
# symoling - 3 it is risky and in 3 it is risky.
# aspiration mans engine type

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %%
car = pd.read_csv("Car_price_Assignment_1.csv")

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car.describe(include='all')
# Out:
#             car_ID   symboling        CarName fueltype aspiration doornumber  \
# count   205.000000  205.000000            205      205        205        205
# unique         NaN         NaN            147        2          2          2
# top            NaN         NaN  toyota corona      gas        std       four
# freq           NaN         NaN              6      185        168        115
# mean    103.000000    0.834146            NaN      NaN        NaN        NaN
# std      59.322565    1.245307            NaN      NaN        NaN        NaN
# min       1.000000   -2.000000            NaN      NaN        NaN        NaN
# 25%      52.000000    0.000000            NaN      NaN        NaN        NaN
# 50%     103.000000    1.000000            NaN      NaN        NaN        NaN
# 75%     154.000000    2.000000            NaN      NaN        NaN        NaN
# max     205.000000    3.000000            NaN      NaN        NaN        NaN
#
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car.cylindernumber.unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
car.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
category = ["CarName","fueltype","aspiration","doornumber","carbody","drivewheel","enginelocation","enginelocation","fuelsystem"]
for i in category:
    car[i] = car[i].astype('category')

# %%
car = car.astype({"symboling":'category'})

# %%
car = car.astype({"doornumber":'category'})

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    category
#  2   CarName           205 non-null    category
#  3   fueltype          205 non-null    category
#  4   aspiration        205 non-null    category
#  5   doornumber        205 non-null    category
#  6   carbody           205 non-null    category
#  7   drivewheel        205 non-null    category
#  8   enginelocation    205 non-null    category
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car.shape
# Out:
# (205, 26)

# %%
msno.bar(car)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(car)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(car)   # here is no pattern.
# Out:
# C:\anaconda\lib\site-packages\seaborn\matrix.py:301: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# C:\anaconda\lib\site-packages\seaborn\matrix.py:301: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <AxesSubplot:>

# %%
sns.boxplot(x="drivewheel",y="wheelbase",data=car)
# Out:
# <AxesSubplot:xlabel='drivewheel', ylabel='wheelbase'>

# %%
sns.violinplot(x="drivewheel",y="enginesize",data=car)
# Out:
# <AxesSubplot:xlabel='drivewheel', ylabel='enginesize'>

# %% [markdown]
# ### Univariate analysis.

# %%
sns.set_palette('mako')

# %%
sns.histplot(data=car['wheelbase'],kde=True)
plt.axvline(x=car.wheelbase.mean(),color='red',alpha=0.5,label='mean')
plt.axvline(x=car.wheelbase.median(),color='blue',alpha=0.5,ls='--',label='median')
plt.show()

# %%
sns.histplot(data=car['enginesize'],kde=True)
plt.axvline(x=car.enginesize.mean(),color='red',alpha=0.5,label='mean')
plt.axvline(x=car.enginesize.median(),color='blue',alpha=0.5,ls='--',label='median')
plt.show()

# %%
sns.histplot(data=car['stroke'],kde=True)
plt.axvline(x=car.stroke.mean(),color='red',alpha=0.5,label='mean')
plt.axvline(x=car.stroke.median(),color='blue',alpha=0.5,ls='--',label='median')
plt.show()

# %%
sns.histplot(data=car['boreratio'],kde=True)
plt.axvline(x=car.boreratio.mean(),c='red',alpha=0.5,label='mean')
plt.axvline(x=car.boreratio.median(),c='blue',ls='--',alpha=0.5,label='median')
plt.show()

# %%
sns.histplot(data=car['compressionratio'],kde=True)
plt.axvline(x=car.compressionratio.mean(),c='red',alpha=0.5,label='mean')
plt.axvline(x=car.compressionratio.median(),c='blue',alpha=0.5,label='median')
plt.show()

# %%
sns.histplot(data=car['horsepower'],kde=True)
plt.axvline(x=car.horsepower.mean(),c='red',alpha=0.5,label='mean')
plt.axvline(x=car.horsepower.median(),c='blue',alpha=0.5,label='median')
plt.show()

# %%
sns.histplot(data=car['peakrpm'],kde=True)
plt.axvline(x=car.peakrpm.mean(),c='red',alpha=0.5,label='mean')
plt.axvline(x=car.peakrpm.median(),c='blue',alpha=0.5,label='median')
plt.show()

# %%
sns.histplot(data=car['citympg'],kde=True)
plt.axvline(x=car.citympg.mean(),c='red',alpha=0.5,label='mean')
plt.axvline(x=car.citympg.median(),c='blue',alpha=0.5,label='median')
plt.show()

# %%
sns.histplot(data=car['highwaympg'],kde=True)
plt.axvline(x=car.highwaympg.mean(),c='red',alpha=0.5,label='mean')
plt.axvline(x=car.highwaympg.median(),c='blue',alpha=0.5,label='median')
plt.show()

# %%
sns.histplot(data=car['price'],kde=True)
plt.axvline(x=car.price.mean(),c='red',alpha=0.5,label='mean')
plt.axvline(x=car.price.median(),c='blue',alpha=0.5,label='median')
plt.show()

# %% [markdown]
# ### Univariate analysis with LOG TRANSFORMATION.

# %%
car['stroke'] = np.log(car['stroke'])

# %%
car['enginesize'] = np.log(car['enginesize'])

# %%
car['wheelbase'] = np.log(car['wheelbase'])

# %%
car['boreratio'] = np.log(car['boreratio'])

# %%
car['compressionratio'] = np.log(car['compressionratio'])

# %%
car['horsepower'] = np.log(car['horsepower'])

# %%
car['peakrpm'] = np.log(car['peakrpm'])

# %%
car['citympg'] = np.log(car['citympg'])

# %%
car['highwaympg'] = np.log(car['highwaympg'])

# %%
car['price'] = np.log(car['price'])

# %%
sns.distplot(car['stroke'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stroke', ylabel='Density'>

# %%
sns.distplot(car['enginesize'])  # log transformation
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='enginesize', ylabel='Density'>

# %%
sns.distplot(car['wheelbase'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='wheelbase', ylabel='Density'>

# %%
sns.distplot(car['boreratio'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='boreratio', ylabel='Density'>

# %%
sns.distplot(car['compressionratio'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='compressionratio', ylabel='Density'>

# %%
sns.distplot(car['horsepower'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.distplot(car['peakrpm'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='peakrpm', ylabel='Density'>

# %%
sns.distplot(car['citympg'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='citympg', ylabel='Density'>

# %%
sns.distplot(car['highwaympg'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='highwaympg', ylabel='Density'>

# %%
sns.distplot(car['price'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# ### Univariate analysis with SQRT TRANSFORMATION.

# %%
car['enginesize'] = np.sqrt(car['enginesize'])  # sqrt transformation

# %%
car['wheelbase'] = np.sqrt(car['wheelbase'])

# %%
car['boreratio'] = np.sqrt(car['boreratio'])

# %%
car['stroke'] = np.sqrt(car['stroke'])

# %%
car['compressionratio'] = np.sqrt(car['compressionratio'])

# %%
car['horsepower'] = np.sqrt(car['horsepower'])

# %%
car['peakrpm'] = np.sqrt(car['peakrpm'])

# %%
car['citympg'] = np.sqrt(car['citympg'])

# %%
car['highwaympg'] = np.sqrt(car['highwaympg'])

# %%
car['price'] = np.sqrt(car['price'])

# %%
sns.distplot(car['enginesize'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='enginesize', ylabel='Density'>

# %%
sns.distplot(car['wheelbase'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='wheelbase', ylabel='Density'>

# %%
sns.distplot(car['boreratio'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='boreratio', ylabel='Density'>

# %%
sns.distplot(car['stroke'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stroke', ylabel='Density'>

# %%
sns.distplot(car['compressionratio'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='compressionratio', ylabel='Density'>

# %%
sns.distplot(car['horsepower'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.distplot(car['peakrpm'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='peakrpm', ylabel='Density'>

# %%
sns.distplot(car['citympg'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='citympg', ylabel='Density'>

# %%
sns.distplot(car['highwaympg'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='highwaympg', ylabel='Density'>

# %%
sns.distplot(car['price'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# ### Bivariate analysis.

# %%
sns.boxplot(x="symboling",y="enginesize",data=car)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='enginesize'>

# %%
sns.boxplot(x="fueltype",y="boreratio",data=car)
# Out:
# <AxesSubplot:xlabel='fueltype', ylabel='boreratio'>

# %%
sns.barplot(x="doornumber",y="enginesize",data=car)
# Out:
# <AxesSubplot:xlabel='doornumber', ylabel='enginesize'>

# %%
sns.boxplot(x="carbody",y="price",data=car)
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='price'>

# %%
sns.violinplot(x="aspiration",y="horsepower",data=car)
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='horsepower'>

# %%
sns.scatterplot(x="enginesize",y="peakrpm",data=car)
# Out:
# <AxesSubplot:xlabel='enginesize', ylabel='peakrpm'>

# %% [markdown]
# ### Multivariate analysis.

# %%
sns.boxplot(x="fueltype",y="citympg",hue="doornumber",data=car)
# Out:
# <AxesSubplot:xlabel='fueltype', ylabel='citympg'>

# %%
sns.barplot(x="symboling",y="price",hue="aspiration",data=car)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='price'>

# %%
sns.barplot(x="enginelocation",y="horsepower",hue="fuelsystem",data=car)
# Out:
# <AxesSubplot:xlabel='enginelocation', ylabel='horsepower'>

# %%
sns.scatterplot(x="boreratio",y="price",hue="horsepower",data=car)
# Out:
# <AxesSubplot:xlabel='boreratio', ylabel='price'>

# %%
car.describe(include='all')
# Out:
#             car_ID  symboling      CarName fueltype aspiration doornumber  \
# count   205.000000      205.0          205      205        205        205
# unique         NaN        6.0          147        2          2          2
# top            NaN        0.0  peugeot 504      gas        std       four
# freq           NaN       67.0            6      185        168        115
# mean    103.000000        NaN          NaN      NaN        NaN        NaN
# std      59.322565        NaN          NaN      NaN        NaN        NaN
# min       1.000000        NaN          NaN      NaN        NaN        NaN
# 25%      52.000000        NaN          NaN      NaN        NaN        NaN
# 50%     103.000000        NaN          NaN      NaN        NaN        NaN
# 75%     154.000000        NaN          NaN      NaN        NaN        NaN
# max     205.000000        NaN          NaN      NaN        NaN        NaN
#
#        carbody drivewheel enginelocation   wheelbase  ...  enginesize  \
# ...
